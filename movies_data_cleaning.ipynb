# %%
import pandas as pd

# %%
#Read data from file
df = pd.read_csv(r'I:\Python Learnings\Bechdel Data\movies.csv')
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
#drop columns
df = df.drop(columns=['id','keywords','runtime','popularity','cast','homepage','tagline','overview','production_companies','budget_adj','revenue_adj'])
df.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#            director                                     genres release_date  \
# 0   Colin Trevorrow  Action|Adventure|Science Fiction|Thriller       6/9/15
# 1     George Miller  Action|Adventure|Science Fiction|Thriller      5/13/15
# 2  Robert Schwentke         Adventure|Science Fiction|Thriller      3/18/15
# 3       J.J. Abrams   Action|Adventure|Science Fiction|Fantasy     12/15/15
# 4         James Wan                      Action|Crime|Thriller       4/1/15
#
#    vote_count  vote_average  release_year
# 0        5562           6.5          2015
# ...

# %%
df.dtypes
# Out:
# imdb_id            object
# budget              int64
# revenue             int64
# original_title     object
# director           object
# genres             object
# release_date       object
# vote_count          int64
# vote_average      float64
# release_year        int64
# dtype: object

# %%
df['director'] = df['director'].str.strip()
df['release_date'] = pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_22452\2080730742.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date'] = pd.to_datetime(df['release_date'])
# imdb_id                   object
# budget                     int64
# revenue                    int64
# original_title            object
# director                  object
# genres                    object
# release_date      datetime64[ns]
# vote_count                 int64
# vote_average             float64
# release_year               int64
# dtype: object

# %%
df.head(2)
# Out:
#      imdb_id     budget     revenue      original_title         director  \
# 0  tt0369610  150000000  1513528810      Jurassic World  Colin Trevorrow
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road    George Miller
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller   2015-06-09        5562
# 1  Action|Adventure|Science Fiction|Thriller   2015-05-13        6185
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015

# %%
df['genres'] = df['genres'].str.split('|')
df.head(2)
# Out:
#      imdb_id     budget     revenue      original_title         director  \
# 0  tt0369610  150000000  1513528810      Jurassic World  Colin Trevorrow
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road    George Miller
#
#                                            genres release_date  vote_count  \
# 0  [Action, Adventure, Science Fiction, Thriller]   2015-06-09        5562
# 1  [Action, Adventure, Science Fiction, Thriller]   2015-05-13        6185
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015

# %%
df.isnull().sum()
# Out:
# imdb_id           10
# budget             0
# revenue            0
# original_title     0
# director          44
# genres            23
# release_date       0
# vote_count         0
# vote_average       0
# release_year       0
# dtype: int64

# %%
df = df.dropna(how = 'any', subset=['imdb_id','director','genres'])
df.isnull().sum()
# Out:
# imdb_id           0
# budget            0
# revenue           0
# original_title    0
# director          0
# genres            0
# release_date      0
# vote_count        0
# vote_average      0
# release_year      0
# dtype: int64

# %%
int(df['imdb_id'].duplicated().sum())
# Out:
# 1

# %%
df = df.drop_duplicates(subset='imdb_id', keep='first')
int(df['imdb_id'].duplicated().sum())
# Out:
# 0

# %%
df.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#            director                                          genres  \
# 0   Colin Trevorrow  [Action, Adventure, Science Fiction, Thriller]
# 1     George Miller  [Action, Adventure, Science Fiction, Thriller]
# 2  Robert Schwentke          [Adventure, Science Fiction, Thriller]
# 3       J.J. Abrams   [Action, Adventure, Science Fiction, Fantasy]
# 4         James Wan                       [Action, Crime, Thriller]
#
#   release_date  vote_count  vote_average  release_year
# 0   2015-06-09        5562           6.5          2015
# ...

# %%
df.to_csv(r'I:\Python Learnings\Bechdel Data\Cleaned_movies.csv', index=False)
